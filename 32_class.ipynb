# %% [markdown]
# ## 클래스와 메서드 만들기

# %%
class person:
    def greeting(self):
        print('Hello')

# %%
# james는 person클래스의 인스턴스이다.
james = person()

# %%
james.greeting()
# Out:
# Hello

# %% [markdown]
# ## 속성 사용하기

# %%
class Person:
    def __init__(self):
        self.hello = '안녕하세요.'
 
    def greeting(self):
        print(self.hello)
 
james = Person()
james.greeting()    # 안녕하세요. *greeting = 인사
# Out:
# 안녕하세요.

# %%
class Person:
    def __init__(self):
        self.hello = '안녕하세요.'
 
    def greeting(self):
        print(self.hello)

jane = Person()
jane.greeting()
# Out:
# 안녕하세요.

# %%
class Person:
    # 속성
    def __init__(self,name,age, address):
        self.hello = "안녕하세요"
        self.name = name
        self.age = age
        self.address = address #매개변수를 가지고 옴
    
    # 매소드
    def greeting(self):
        print(f"{self.hello} 저는 {self.name} 입니다.")
        

maria = Person("마리아",20,"서울시 서초구 반포동")
maria.greeting()
# Out:
# 안녕하세요 저는 마리아 입니다.

# %%
print("이름 : ",maria.name)
print("나이 : ",maria.age)
print("주소 : ",maria.address)
# Out:
# 이름 :  마리아
# 나이 :  20
# 주소 :  서울시 서초구 반포동

# %% [markdown]
# ## 비공개 속성 사용하기

# %%
class Person:
    # 속성
    def __init__(self,name,age, address,wallet):
        self.hello = "안녕하세요"
        self.name = name
        self.age = age
        self.address = address #매개변수를 가지고 옴
        self.__wallet = wallet

    # 매소드
    def greeting(self):
        print(f"{self.hello} 저는 {self.name} 입니다.")
        

maria = Person("마리아",20,"서울시 서초구 반포동",10000)
maria.greeting()
maria.__wallet
# Out:
# 안녕하세요 저는 마리아 입니다.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 17
#      13
#      14
#      15 maria = Person("마리아",20,"서울시 서초구 반포동",10000)
#      16 maria.greeting()
# ---> 17 maria.__wallet
#
# AttributeError: 'Person' object has no attribute '__wallet'

# %%
class Person:
    # 속성
    # 클래스로 인스턴스를 만들 때 호출되는 메서드 __init__
    def __init__(self,name,age, address,wallet):
        self.hello = "안녕하세요"
        self.name = name
        self.age = age
        self.address = address #매개변수를 가지고 옴
        self.__wallet = wallet

    # 매소드
    def greeting(self):
        print(f"{self.hello} 저는 {self.name} 입니다.")
    
    def pay(self, amount):
        if amount > self.__wallet:
            print('잔액부족')
        else:
            self.__wallet -= amount
            print(f'이제 {self.__wallet}원 남았습니다.')
            

maria = Person("마리아",20,"서울시 서초구 반포동",10000)
maria.greeting()
maria.pay(10000)
# Out:
# 안녕하세요 저는 마리아 입니다.
# 이제 0원 남았습니다.

# %% [markdown]
# ## 연습문제

# %%
class Knight:
    def __init__(self,health,mana,armor):
        self.health = health
        self.mana = mana
        self.armor = armor

    def slash(self):
        print("베기")


x = Knight(health=542.4, mana=210.3, armor=38)
print(x.health, x.mana, x.armor)
x.slash()
# Out:
# 542.4 210.3 38
# 베기

# %% [markdown]
# ## 심사문제

# %%
class  Annie:
    def __init__(self,health,mana,ability_power):
        self.health = health
        self.mana = mana
        self.ability_power = ability_power
    
    def tibbers(self):
        damage = self.ability_power * 0.65 + 400
        print(f"티버: 피해량 {damage}")
        

health, mana, ability_power = map(float, input().split())
 
x = Annie(health=health, mana=mana, ability_power=ability_power)
x.tibbers()
# Out:
# 티버: 피해량 593.7
