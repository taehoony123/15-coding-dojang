# %% [markdown]
# ## 클래스 속성과 정적, 클래스 메서드 사용하기

# %%
class Person:
    bag = []
 
    def put_bag(self, stuff):
        self.bag.append(stuff)
 
james = Person()
james.put_bag('책')

maria = Person()
maria.put_bag('열쇠')

print(james.bag)
print(maria.bag)
# Out:
# ['책', '열쇠']
# ['책', '열쇠']

# %% [markdown]
# 클래스 속성은 클래스에 속해 있으며 모든 인스턴스에서 공유합니다.

# %%
print(Person.bag)
# Out:
# ['책', '열쇠']

# %% [markdown]
# ## 인스턴스 속성 사용하기

# %%
class Person:
    def __init__(self):
        self.bag = []

    def put_bag(self, stuff):
        self.bag.append(stuff)
 
james = Person()
james.put_bag('책')

maria = Person()
maria.put_bag('열쇠')

print(james.bag)
print(maria.bag)
# Out:
# ['책']
# ['열쇠']

# %% [markdown]
# ## 비공개 클래스 속성 사용하기

# %%
class Knight:
    __item_limit = 10    # 비공개 클래스 속성
 
    def print_item_limit(self):
        print(Knight.__item_limit)    # 클래스 안에서만 접근할 수 있음
 
 
x = Knight()
x.print_item_limit()    # 10
 
print(Knight.__item_limit)    # 클래스 바깥에서는 접근할 수 없음
# Out:
# 10
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 11
#       7
#       8 x = Knight()
#       9 x.print_item_limit()    # 10
#      10
# ---> 11 print(Knight.__item_limit)    # 클래스 바깥에서는 접근할 수 없음
#
# AttributeError: type object 'Knight' has no attribute '__item_limit'

# %% [markdown]
# ## 정적메서드 사용

# %%
class Calc:
    @staticmethod
    def add(a,b):
        print(a+b) 
    @staticmethod
    def mul(a,b):
        print(a*b) 

Calc.add(10,20)
Calc.mul(10,20)
# Out:
# 30
# 200

# %% [markdown]
# ## 클래스 메서드 사용

# %%
# class 클래스이름:
#     @classmethod
#     def 매서드(cls, 매개변수1, 매개변수2):
#         코드

# %%
class Person:
    count = 0
    def __init__(self):
        Person.count += 1
    
    @classmethod
    def print_count(cls):
        print(f"{cls.count}명 생성되었습니다.")

james = Person()
maria = Person()

Person.print_count()
# Out:
# 2명 생성되었습니다.

# %%
a = 30
b = 8
c = a//b
d = a%b
e = a/b

print(f"{a}를 {b}로 나눈 몫은 {c}")
print(f"{a}를 {b}로 나눈 나머지는 {d}")
print(f"{a}를 {b}로 나눈 결과는 {e}")
# Out:
# 30를 8로 나눈 몫은 3
# 30를 8로 나눈 나머지는 6
# 30를 8로 나눈 결과는 3.75
