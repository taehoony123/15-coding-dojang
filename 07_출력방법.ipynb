# %%
# 값을 여러개 출력하기 

print(1, 2, 3)
# Out:
# 1 2 3

# %%
# sep로 값 사이에 문자넣기 
print(1, 2, 3, sep=", ")
# Out:
# 1, 2, 3

# %%
print(1920, 1000, sep="x")
# Out:
# 1920x1000

# %%
# 줄바꿈 활용하기 
print(1, 2, 3, sep="\n")
# Out:
# 1
# 2
# 3

# %%
print("1\n2\n3")
# Out:
# 1
# 2
# 3

# %%
# end 사용하기
print(1)
print(2)
print(3)
# Out:
# 1
# 2
# 3

# %%
print(1, end="")
print(2, end="")
print(3)
# Out:
# 123

# %%
print(1, end=" ")
print(2, end=" ")
print(3)

print(1, 2, 3)
# Out:
# 1 2 3
# 1 2 3
