# %%
x = 10

if x == 10:
    print("10입니다.")
# Out:
# 10입니다.

# %%
x = 10

if x == 10:
    print("x의 들어있는 숫자는")
    print("10입니다.")
# Out:
# x의 들어있는 숫자는
# 10입니다.

# %%
x = 10

if x == 10:
    print("x의 들어있는 숫자는")
print("10입니다.")
# Out:
# x의 들어있는 숫자는
# 10입니다.

# %%
# 중첩 if문 사용하기
x = 10
if x >= 10:
    print("10 이상")
    if x == 10:
        print("10 이다")
    if x == 20:
        print("20 이다")
# Out:
# 10 이상
# 10 이다

# %%
x = int(input("숫자를 입력하세요"))
if x == 10:
    print("10입니다.")

if x == 20:
    print("20입니다.")
# Out:
# 20입니다.

# %%
a = int(input())
b = str(input())
if b == "Cash3000":
    print(a - 3000)
else :
    print(a - 5000)
# Out:
# 24000
