# %% [markdown]
# # 세미콜론
# ## 구문이 끝날때 ;

# %%
1+1
# Out:
# 2

# %%
# 주석
# 코드실행에 영향을 받지 않는다
# 비주얼 스튜디오 코드에서는 'ctrl + /' 설정이 가능하다(한 줄 주석, 블록 주석)

# %%
# 들여쓰기
## 공백 2칸 또는 공백 4칸
## 들여쓰기 자체가 문법이다.

# %%
# 코드 블록
## 들여쓰기를 기준으로 코드 블록 구성

a = 12

if a == 12: 
    print("12 입니다.")
