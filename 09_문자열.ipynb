# %%
hello = "Hello World!"
hello
# Out:
# 'Hello World!'

# %%
hello = "안녕하세요"
hello
# Out:
# '안녕하세요'

# %%
hello = '''Hello, World!'''
hello
# Out:
# 'Hello, World!'

# %%
python = """Python Programming"""
python
# Out:
# 'Python Programming'

# %%
# 여러줄로 된 문자열 사용하기
hello = '''Hello, World!
안녕하세요
Python입니다.'''

print(hello)
# Out:
# Hello, World!
# 안녕하세요
# Python입니다.

# %%
# 문자열 안에 작은따옴표나 큰따옴표 포함하기
s = "Python isn't difficult"
s
# Out:
# "Python isn't difficult"

# %%
s = "He \'sa\nid \"Python \tis \\easy\""
print(s)
# Out:
# He 'sa
# id "Python 	is \easy"

# %%
name = "켄"
f"안녕 {name} 입니다"
# Out:
# '안녕 켄 입니다'

# %%
nmae = "켄"
`안녕 {name} 입니다`
