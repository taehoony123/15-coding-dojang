# %%
# 불과 비교 연산자 사용하기 

True
False
# Out:
# False

# %%
# 비교 연산자의 판단 결과 

3 > 1
# Out:
# True

# %%
# 숫자 같은지 비교 
10 == 10
# Out:
# True

# %%
print("Python" == "Python")
print("Python" == "python")   
print("Python" != "python")   # <>
# Out:
# True
# False
# True

# %%
# 부등호 사용하기 
print(10 > 20)
print(10 < 20)
print(10 >= 10)
print(10 <= 10)
# Out:
# False
# True
# True
# True

# %%
# 객체가 같은지 다른지 비교하기 
print(1 == 1.0)
print(1 is 1.0)
# Out:
# True
# False
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\PC\AppData\Local\Temp\ipykernel_12188\622540286.py:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(1 is 1.0)

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
1 is not 1.0
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\PC\AppData\Local\Temp\ipykernel_12188\2095918375.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   1 is not 1.0
# True

# %%
# 논리 연산자 사용하기 
## AND
print(True and True)
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
# OR
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
not True and False or not False
# Out:
# True

# %%
((not True) and False) or (not False)
# Out:
# True

# %%
# 논리연산자와 비교연산자 사용

print((10 == 10) and (10 != 5))

print((10 > 5) or (10 < 3))

print(not 10 > 5) 

print(not 1 is 1.0)
# Out:
# True
# True
# False
# True
# <>:9: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:9: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\PC\AppData\Local\Temp\ipykernel_12188\2513494738.py:9: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(not 1 is 1.0)

# %%
(not 10) == 0
# Out:
# True

# %%
kor, eng, math, sci = map(int, input().split())

kor >= 90 and eng > 80 and math > 85 and sci >= 80
# Out:
# True
